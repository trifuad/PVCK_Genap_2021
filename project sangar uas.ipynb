# %% [markdown]
# <a href="https://colab.research.google.com/github/trifuad/PVCK_Genap_2021/blob/main/project%20sangar%20uas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import math
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/PCVK_MM/dataset/sampel data 15.png')
plt.imshow(img)
img.shape
# Out:
# (120, 240, 3)

# %%
img[:,:,0] #blue
# Out:
# array([[33, 34, 38, ..., 46, 63, 76],
#        [25, 26, 28, ..., 56, 75, 85],
#        [25, 26, 26, ..., 59, 77, 87],
#        ...,
#        [23, 26, 34, ..., 33, 32, 36],
#        [25, 25, 30, ..., 34, 32, 30],
#        [25, 26, 29, ..., 33, 28, 27]], dtype=uint8)

# %%
img[:,:,1] #green
# Out:
# array([[45, 47, 51, ..., 50, 66, 78],
#        [34, 36, 39, ..., 60, 78, 87],
#        [34, 36, 36, ..., 63, 80, 89],
#        ...,
#        [27, 30, 38, ..., 34, 32, 39],
#        [29, 29, 34, ..., 35, 32, 32],
#        [29, 30, 33, ..., 34, 29, 28]], dtype=uint8)

# %%
img[:,:,2] #red
# Out:
# array([[47, 49, 51, ..., 39, 55, 63],
#        [39, 41, 42, ..., 49, 67, 72],
#        [40, 42, 42, ..., 52, 69, 74],
#        ...,
#        [22, 25, 33, ..., 26, 23, 27],
#        [24, 24, 29, ..., 27, 25, 22],
#        [24, 25, 28, ..., 26, 21, 19]], dtype=uint8)

# %%
hasil = []

for x in range(0,img.shape[0]):
    row = []
    for y in range(0, img.shape[1]):
        blue = img[x,y,0] - 35
        green = img[x,y,1] - 35
        red = img[x,y,2] - 160
        blue = blue**2
        green = green**2
        red = red**2
        tambahRGB = blue + green + red
        akar = math.sqrt(tambahRGB)
        if akar > 55:
            row.append(0)
        else:
            row.append(255)
    hasil.append(row)

# %%
segar = True
for i in hasil:
    for j in i:
        if j > 0:
            segar = False
            break;

# %%
if segar:
    print("ikan Segar")
else:
    print("ikan Tidak Segar")
# Out:
# ikan Tidak Segar
